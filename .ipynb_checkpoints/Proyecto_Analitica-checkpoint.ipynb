# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('computer_prices_all.csv')
df.head()
# Out:
#   device_type     brand              model  release_year       os form_factor  \
# 0     Desktop   Samsung  Samsung Forge XDI          2022  Windows         ATX
# 1      Laptop   Samsung    Samsung Pro KM8          2022  Windows  Mainstream
# 2     Desktop    Lenovo   Lenovo Strix BIE          2024    macOS         SFF
# 3     Desktop      Dell      Dell Cube AXR          2024  Windows         ATX
# 4      Laptop  Gigabyte   Gigabyte Pro IX1          2024    Linux      Gaming
#
#   cpu_brand         cpu_model  cpu_tier  cpu_cores  ...  resolution  \
# 0     Intel    Intel i5-11129         3         12  ...   2560x1440
# 1     Intel    Intel i7-11114         4         12  ...   1920x1080
# 2       AMD  AMD Ryzen 5 5168         2          8  ...   3440x1440
# 3       AMD  AMD Ryzen 5 7550         2          6  ...   3440x1440
# 4       AMD  AMD Ryzen 7 6230         5         16  ...   2560x1600
#
#    refresh_hz  battery_wh charger_watts psu_watts     wifi  bluetooth  \
# 0          90           0             0       750  Wi-Fi 6        5.1
# 1          90          56           120         0  Wi-Fi 6        5.3
# 2         120           0             0       850  Wi-Fi 6        5.0
# 3         120           0             0       650  Wi-Fi 6        5.2
# 4          90          80            90         0  Wi-Fi 6        5.2
#
#    weight_kg warranty_months    price
# 0      11.00              36  1383.99
# 1       2.03              12  2274.99
# 2       7.00              24  1879.99
# 3       6.00              36  1331.99
# 4       1.50              12  2681.99
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (100000, 33)

# %%
df.columns
# Out:
# Index(['device_type', 'brand', 'model', 'release_year', 'os', 'form_factor',
#        'cpu_brand', 'cpu_model', 'cpu_tier', 'cpu_cores', 'cpu_threads',
#        'cpu_base_ghz', 'cpu_boost_ghz', 'gpu_brand', 'gpu_model', 'gpu_tier',
#        'vram_gb', 'ram_gb', 'storage_type', 'storage_gb',
#        'storage_drive_count', 'display_type', 'display_size_in', 'resolution',
#        'refresh_hz', 'battery_wh', 'charger_watts', 'psu_watts', 'wifi',
#        'bluetooth', 'weight_kg', 'warranty_months', 'price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# device_type            0
# brand                  0
# model                  0
# release_year           0
# os                     0
# form_factor            0
# cpu_brand              0
# cpu_model              0
# cpu_tier               0
# cpu_cores              0
# cpu_threads            0
# cpu_base_ghz           0
# cpu_boost_ghz          0
# gpu_brand              0
# gpu_model              0
# gpu_tier               0
# vram_gb                0
# ram_gb                 0
# storage_type           0
# storage_gb             0
# storage_drive_count    0
# display_type           0
# display_size_in        0
# resolution             0
# refresh_hz             0
# battery_wh             0
# charger_watts          0
# psu_watts              0
# wifi                   0
# bluetooth              0
# weight_kg              0
# warranty_months        0
# price                  0
# dtype: int64

# %%
df['id'] = range(1, len(df) + 1)
df = df[df["release_year"] != 2025].copy()
df.to_excel('computer_prices_all.xlsx', index=False)

# %%
df["brand"].value_counts()
# Out:
# brand
# Lenovo      13451
# HP          11932
# Dell        11866
# Apple        9987
# ASUS         8572
# Acer         8340
# Samsung      6738
# MSI          6628
# Gigabyte     4116
# Razer        2535
# Name: count, dtype: int64

# %%
df["ram_gb"].value_counts()
# Out:
# ram_gb
# 32     18976
# 16     18696
# 8      15459
# 64     14371
# 96      7762
# 128     2163
# 24      1916
# 40      1671
# 72      1331
# 104      677
# 48       415
# 80       318
# 136      203
# 112      163
# 144       44
# Name: count, dtype: int64

# %%
df.loc[df['brand'] == 'Apple', 'ram_gb'].unique()
# Out:
# array([  8,  32,  96, 144,  16, 128,  64,  72,  48, 104,  24,  40, 136,
#         80, 112])

# %%
df.loc[df["brand"] == "Apple", "ram_gb"].value_counts()
# Out:
# ram_gb
# 32     2234
# 64     1968
# 16     1782
# 96     1496
# 8      1020
# 128     611
# 72      201
# 40      183
# 24      183
# 104     114
# 80       60
# 136      48
# 48       46
# 112      32
# 144       9
# Name: count, dtype: int64

# %%
df["cpu_tier"].unique()
# Out:
# array([3, 4, 2, 5, 6, 1])

# %%
df["cpu_tier"].value_counts().sort_index()
# Out:
# cpu_tier
# 1    10813
# 2    17908
# 3    21699
# 4    18736
# 5    10902
# 6     4107
# Name: count, dtype: int64

# %%
df.groupby("cpu_tier")["cpu_model"].value_counts()
# Out:
# cpu_tier  cpu_model
# 1         Apple M2 Pro      75
#           Apple M3          71
#           Apple M3 Max      66
#           Apple M2          62
#           Apple M1          57
#                             ..
# 6         Intel i9-14984     1
#           Intel i9-14988     1
#           Intel i9-14989     1
#           Intel i9-14993     1
#           Intel i9-14997     1
# Name: count, Length: 36919, dtype: int64

# %%
df.groupby("cpu_tier")[["cpu_cores", "cpu_threads", "cpu_boost_ghz"]].mean() #para saber que compone la escala del 1 al 6 de cpu_tier
# Out:
#           cpu_cores  cpu_threads  cpu_boost_ghz
# cpu_tier
# 1          4.743549     9.061870       3.101591
# 2          6.778981    12.757874       3.304981
# 3          8.758560    16.372460       3.500760
# 4         12.767933    23.705167       3.696483
# 5         16.760961    30.520455       3.898725
# 6         24.754809    42.576577       4.102143

# %%
df.loc[df["cpu_tier"] == 1, "cpu_cores"].unique()
# Out:
# array([4, 6, 8])

# %%
df.loc[df["cpu_tier"] == 2, "cpu_cores"].unique()
# Out:
# array([ 8,  6, 10])

# %%
df.loc[df["cpu_tier"] == 3, "cpu_cores"].unique()
# Out:
# array([12,  8, 10])

# %%
df.loc[df["cpu_tier"] == 4, "cpu_cores"].unique()
# Out:
# array([12, 14, 16])

# %%
df.loc[df["cpu_tier"] == 5, "cpu_cores"].unique()
# Out:
# array([16, 18, 20])

# %%
df.loc[df["cpu_tier"] == 6, "cpu_cores"].unique()
# Out:
# array([26, 24, 28])

# %%
#PCA

# %%
df.dtypes != object
# Out:
# device_type            False
# brand                  False
# model                  False
# release_year            True
# os                     False
# form_factor            False
# cpu_brand              False
# cpu_model              False
# cpu_tier                True
# cpu_cores               True
# cpu_threads             True
# cpu_base_ghz            True
# cpu_boost_ghz           True
# gpu_brand              False
# gpu_model              False
# gpu_tier                True
# vram_gb                 True
# ram_gb                  True
# storage_type           False
# storage_gb              True
# storage_drive_count     True
# display_type           False
# display_size_in         True
# resolution             False
# refresh_hz              True
# battery_wh              True
# charger_watts           True
# psu_watts               True
# wifi                   False
# bluetooth               True
# weight_kg               True
# warranty_months         True
# price                   True
# id                      True
# dtype: bool

# %%
columnas_num = ["release_year", "cpu_tier", "cpu_cores","cpu_threads","cpu_base_ghz", "cpu_boost_ghz", "gpu_tier", "vram_gb","ram_gb", "storage_gb", 
    "storage_drive_count", "display_size_in", "refresh_hz", "battery_wh", "charger_watts", "psu_watts", "bluetooth", "weight_kg","warranty_months",
    "price", "id"]

X = df[columnas_num]

# %%
from sklearn.preprocessing import StandardScaler #estandarizamos los datos 

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#qplicamos PCA
from sklearn.decomposition import PCA

pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
pca_3 = PCA(n_components=3)
X_pca_3 = pca_3.fit_transform(X_scaled)

df_pca = pd.DataFrame(X_pca_3,columns=["1", "2", "3"])
df_pca
# Out:
#               1         2         3
# 0      0.937742 -2.618254 -0.098558
# 1      0.712342  2.112599 -0.005154
# 2     -0.267861 -3.308424  0.817481
# 3     -0.616487 -2.887231  0.533054
# 4      2.715183  3.153892  0.256071
# ...         ...       ...       ...
# 84160 -0.397277  2.380776  1.326885
# 84161 -2.960650  0.257507 -1.220847
# 84162 -3.197513  1.647482 -0.751543
# 84163 -0.044091  1.683834 -0.981270
# 84164  6.882408  0.419919  1.410739
#
# [84165 rows x 3 columns]

# %%
loadings = pd.DataFrame( #CHAT 
    pca_3.components_.T,
    columns=["PC1", "PC2", "PC3"],
    index=X.columns
)

loadings.sort_values("PC1", ascending=False)
# Out:
#                           PC1       PC2       PC3
# cpu_base_ghz         0.365059 -0.063358 -0.007736
# cpu_boost_ghz        0.354669 -0.062070 -0.008782
# ram_gb               0.324812  0.185947 -0.013462
# cpu_cores            0.323550  0.188909 -0.020729
# cpu_tier             0.323259  0.206184 -0.015166
# gpu_tier             0.321398  0.159856 -0.007329
# cpu_threads          0.303396  0.177034 -0.066436
# price                0.241794  0.242988  0.194128
# vram_gb              0.182647  0.092816 -0.103550
# psu_watts            0.165930 -0.383467  0.011640
# display_size_in      0.165730 -0.382626  0.009139
# weight_kg            0.154951 -0.362385  0.010362
# storage_drive_count  0.102475 -0.249960  0.027757
# refresh_hz           0.004672  0.003975  0.454910
# release_year         0.003575  0.006174  0.508543
# storage_gb           0.002777  0.007962  0.652851
# id                   0.001330  0.004266 -0.110092
# bluetooth           -0.000946 -0.001430  0.139369
# warranty_months     -0.001075  0.001614 -0.146790
# charger_watts       -0.146277  0.344049 -0.011719
# battery_wh          -0.167731  0.386061 -0.006916

# %%
pd.DataFrame({ #CHAT
    "Componente": ["PC1", "PC2", "PC3"],
    "Varianza explicada": pca_3.explained_variance_ratio_,
    "Varianza acumulada": pca_3.explained_variance_ratio_.cumsum()
})
# Out:
#   Componente  Varianza explicada  Varianza acumulada
# 0        PC1            0.335494            0.335494
# 1        PC2            0.225232            0.560726
# 2        PC3            0.048908            0.609634
